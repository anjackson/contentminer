# %%
# !ami-search -p ethos-viral -forcemake --dictionary=country --dictionary=sars_covid_2
# Out:
# Unknown option: '-forcemake'
# Possible solutions: --forcemake
#
# Generic values (AMISearchTool)
# ...
# -v to see generic values
# oldstyle            true
#
# Specific values (AMISearchTool)
# ...
# oldstyle             true
# strip numbers        false
# wordCountRange       (20,1000000)
# wordLengthRange      (1,20)
#
# dictionaryList       [country, sars_covid_2]
# dictionaryTop        null
# dictionarySuffix     [xml]
#
# 0    [main] DEBUG org.contentmine.ami.tools.AbstractAMISearchTool  - old style search command); change
# 0 [main] DEBUG org.contentmine.ami.tools.AbstractAMISearchTool  - old style search command); change
# cProject: ethos-viral
# legacy cmd> word(frequencies)xpath:@count>20~w.stopwords:pmcstop.txt_stopwords.txt
# legacy cmd> search(country)
# legacy cmd> search(sars_covid_2)
# ...

# %%
from IPython.display import IFrame,display

display(IFrame(src="ethos-viral/full.dataTables.html", width="100%", height="300px"))
# Out:
#         <iframe
#             width="100%"
#             height="300px"
#             src="ethos-viral/full.dataTables.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
display(IFrame(src="ethos-viral/__cooccurrence/allPlots.svg", width="90%", height="350px"))
# Out:
#         <iframe
#             width="90%"
#             height="350px"
#             src="ethos-viral/__cooccurrence/allPlots.svg"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
